# %%
import json
import pandas as pd
import numpy as np

# %%
with open("../data/MC1_preprocessed.json", "r") as f:
    data = json.load(f)

df = pd.DataFrame(data['nodes'])

# %%
df.head()
# Out:
#            type dataset   country                          id
# 0       company     MC1  Nalakond  spanish shrimp  carriers|0
# 1  organization     MC1       NaN                     12744|1
# 2  organization     MC1       NaN                 143129355|2
# 3  organization     MC1       NaN                      7775|3
# 4  organization     MC1       NaN                   1017141|4

# %% [markdown]
# ## Entity types

# %%
for type in df['type'].unique():
    if not pd.isna(type):
        print(f"{type}")
        print(df[df['type']==type]['id'][:5].tolist())
        print()
# Out:
# company
# ['spanish shrimp  carriers|0', 'faroe islands shrimp shark|7', 'saltwater solitude gmbh & co. kg|24', 'viento azul harbor llc investment|115', 'turkish sword buoy incorporated forwading|183']
#
# organization
# ['12744|1', '143129355|2', '7775|3', '1017141|4', '2591586|5']
#
# person
# ['william bradley|13', 'joseph griffin|14', 'jacob caldwell|21', 'ann daniels|31', 'stephanie mccormick md|32']
#
# location
# ['4369922c-ce1d-40ff-904c-1f6a3000bf6b|23', 'da0a7bbb-5bd1-42aa-bcc0-b8923d5c15d4|36', '445a6124-4650-4e5a-83bb-a0e0b4040ee9|41', '77b46bc7-7e31-41a0-973c-e633011d21b0|60', 'd0123474-8425-4ab0-90d5-175920158638|92']
#
# political_organization
# ['6406040|63', '72371354|67', '766649|69', '85117949|76', '348079|78']
#
# vessel
# ['marine|102', 'viking fishing|116', '77|1693', 'uss hershel|193', 'uscgc spencer|200']
#
# movement
# ['hours|123', 'months|227', 'weeks|390', 'conjunction|554', 'normal|712']
#
# event
# ['act|212', 'months years|223', 'cookies|237', '|278', 'arts|283']

# %% [markdown]
# ## Entities with missing type

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df[df['type'].isna()]['id'])
# Out:
# 10                                              victim|10
# 11                                         perpetrator|11
# 15                                                    |15
# 25                                                 prk|25
# 26                                              viking|26
# 29                                             regular|29
# 81                                                   8|81
# 82                                               refer|82
# 83                                                  10|83
# 87                                             notices|87
# 103                                            255273|103
# 141                                                st|141
# 166                                     armed robbery|166
# 173                                       unregulated|173
# 206                                              sept|206
# 222                                        convention|222
# 225                                            months|225
# 284                                               98|2691
# 292                                               189|292
# 293                                                07|293
# 299                                         necessary|299
# 327                                             local|327
# 328                           leominster provincetown|328
# 332                                         fisheries|332
# 414                                     devil vessels|414
# 419                                                  |419
# 420                                             e1p|420
# 421                                            e1pp|421
# 422                                                 p|422
# 423                                                  |423
# 424                                                xu|424
# 425                                                  |425
# 426                                                8p|426
# 427                                                 k|427
# 428                                                pj|428
# 429                                                  |429
# 430                                                 b|430
# 431                                               lu|431
# 432                                              ijpk|432
# 433                                                 5|433
# 434                                                  |434
# 435                                                dd|435
# 436                                                  |436
# 437                                                 g|437
# 438                                                 p|438
# 439                                                  |439
# 440                                                 k|440
# 441                                                 i|441
# 442                                                 q|442
# 443                                                gu|443
# 444                                               pm6|444
# 445                                                 z|445
# 446                                                 n|446
# 447                                                 |447
# 448                                             bjnnn|448
# 449                                                 l|449
# 450                                                 |450
# 451                                                5|451
# 452                                                 d|452
# 453                                                 l|453
# 454                                                jo|454
# 455                                                y|455
# 456                                               no|456
# 457                                                 n|457
# 458                                                 z|458
# 459                                                 x|459
# 460                                                ip|460
# 461                                              msss|461
# 462                                                 x|462
# 463                                                 v|463
# 464                                                uk|464
# 465                                            md|465
# 466                                                mk|466
# 467                                              mkf1|467
# 468                                                f1|468
# 469                                               f1f|469
# 501                                         artisanal|501
# 502                                       subsistence|502
# 518                         ebscohostsearched octopus|518
# 519                                       and fishery|519
# 522                                         artisanal|522
# 525                                           octopus|525
# 526                                        cephalopod|526
# 527                                            cyanea|527
# 528                                              maya|528
# 530                                             polvo|530
# 531                                        livelihood|531
# 534                                              folk|534
# 535                                             women|535
# 536                                            fisher|536
# 537                                        management|537
# 538                                                 o|538
# 540                                            poulpe|540
# 542                                             scale|542
# 545                                       alonso-fern|545
# 573                                     europeansting|573
# 608                                               lom|608
# 622                                            states|622
# 648                                aleut community st|648
# 649                                            kanuux|649
# 651                                     sewards folly|651
# 655                                      alaum kanuux|655
# 671                                      alaum kanuux|671
# 697                                           17 sept|697
# 711                                             green|711
# 717                                                di|717
# 718                                              logo|718
# 736                                          ipoa-iuu|736
# 737                           think tank index report|737
# 738                                             upenn|738
# 739                                               edu|739
# 741                                      torremolinos|741
# 742                          international-convention|742
# 743                                               imo|743
# 745                                                 u|745
# 764                                              sink|764
# 778                                          degraded|778
# 785                                     mexicos yucat|785
# 795                                          pioneers|795
# 797                                            zombie|797
# 822                         the pew charitable trusts|822
# 835                                     collaborative|835
# 882                                                  |882
# 929                                               gal|929
# 985                                          presumed|985
# 986                                         confirmed|986
# 997                                        widespread|997
# 999                                         protected|999
# 1012                                           catch|1012
# 1021                                     encountered|1021
# 1039                                        13 years|1039
# 1071                     fisheries animal industries|1071
# 1109                                           abc12|1109
# 1242                                        disaster|1242
# 1265                                         we fins|1265
# 1306                                                |1306
# 1336                                         sampath|1336
# 1368                                   united states|1368
# 1371                                      game thief|1371
# 1377                                   transshipment|1377
# 1404             pacific island states united states|1404
# 1405                        territory american samoa|1405
# 1415                                     eared seals|1415
# 1436                                           holes|1436
# 1440                                         nigeria|1440
# 1454                                    conservative|1454
# 1469                                     aquaculture|1469
# 1472                                  discrimination|1472
# 1483                                              th|1483
# 1485                                          itaqua|1485
# 1497                                      deceuninck|1497
# 1520                                       moby-dick|1520
# 1528                                   theoretically|1528
# 1534                                   seafreeze ltd|1534
# 1545                                             bhf|1545
# 1548                                      propublica|1548
# 1549                                       yesterday|1549
# 1551                                        portland|1551
# 1563                                             415|1563
# 1564                                              60|1564
# 1584                                              93|1781
# 1586                                              96|1586
# 1588                                         flodstr|1588
# 1595                                         carding|1595
# 1613                                       allafrica|1613
# 1615                                               9|1615
# 1635                                             800|1635
# 1685                                           water|1685
# 1701                               nationalfisherman|1701
# 1702                                       intrafish|1702
# 1704                                 choicesmagazine|1704
# 1706                                             usa|1706
# 1707                                          oceana|1707
# 1712                                        ams.usda|1712
# 1714                                       initially|1714
# 1715                             simpcomplianceguide|1715
# 1717                                         poached|1717
# 1724                                      accept all|1724
# 1725                                            krxd|1725
# 1757                                        seamount|1757
# 1765                                            mars|1765
# 1777                                   launch lovers|1777
# 1779                                              lc|1779
# 1825                       us special operations sof|1825
# 1835                                          bosses|1835
# 1850                                            mcdp|1850
# 1885                                        dimersal|1885
# 1896                                          awacha|1896
# 1898                                           saiko|1898
# 1912                                           elqui|1912
# 1998                                   shipping corp|1998
# 2008                                 navigation corp|2008
# 2009                          triton navigation corp|2009
# 2010                          pontus navigation corp|2010
# 2033                                             hsi|2033
# 2034                                            nypd|2034
# 2037                                              be|2037
# 2092                                       laughable|2092
# 2108                                           toppy|2108
# 2109                                            stag|2109
# 2119                                      legitimate|2119
# 2155                                     easterlings|2155
# 2186                                       attorneys|2186
# 2200                                       22 raptor|2200
# 2225                                           covid|2225
# 2231                                       frontline|2231
# 2235                                             the|2235
# 2258                                       survivors|2258
# 2259                                      task force|2259
# 2274                                         filkins|2274
# 2301                                         goliath|2301
# 2305                                             est|2305
# 2306                                        maana as|2306
# 2336                      liibaan general trading co|2336
# 2351                                             rpg|2351
# 2366                                refugee benefits|2366
# 2373                                           perla|2373
# 2374                                       emanuelif|2374
# 2376                                        restrain|2376
# 2382                                    exploitation|2382
# 2390                                             feb|2390
# 2392                                          direct|2392
# 2393                                        directly|2393
# 2404                                            wgbh|2404
# 2407                                    brianbushard|2407
# 2408                                    siladityaray|2408
# 2413                                           perla|2413
# 2428                                          mexico|2428
# 2434                                         enticed|2434
# 2444                                                |2444
# 2445                                                |2445
# 2446                                                |2446
# 2449                                      compromise|2449
# 2450                                        partners|2450
# 2457                           theoriginaldragoncove|2457
# 2473                              originaldragoncove|2473
# 2474                                  the defendants|2474
# 2481                                            nino|2481
# 2501                                           texas|2501
# 2502                                      remarkable|2502
# 2505                                               p|2505
# 2508                                      commission|2508
# 2530                                      undeniable|2530
# 2534                                 inconsistencies|2534
# 2539                                       adjusting|2539
# 2547                                   desbloqueio p|2547
# 2551                                            kiko|2551
# 2556    tio mpfs special action group combat organized...
# 2563                                         exporta|2563
# 2568                                         illegal|2568
# 2578                                       hardwoods|2578
# 2583                                          merida|2583
# 2584                                          merida|2584
# 2590                                         bandera|2590
# 2591                                           padre|2591
# 2597                                         menards|2597
# 2601                                             103|2601
# 2602                                              10|2602
# 2605                                           tiger|2605
# 2619                                          mining|2619
# 2634                                             pit|2634
# 2640                                          snitch|2640
# 2645                                          broker|2645
# 2678                                          platts|2678
# 2710                                    duare ration|2710
# 2780                                    satisfactory|2780
# 2845                                     overwhelmed|2845
# 2904                                       exemplary|2904
# 2932                                      amstel inc|2932
# 2933                                            help|2933
# 2942                                          sleepy|2942
# 2948                                              16|2948
# 2969                                  public loaders|2969
# 2972                                       equipment|2972
# 2987                                           shabu|2987
# 2998                                          crisis|2998
# 3008                              aicrowe biotech co|3008
# 3013                       gaosheng biotechnology co|3013
# 3019                                             076|3019
# 3020                                            vans|3020
# 3025                                      disastrous|3025
# 3043                                       shark fin|3043
# 3063                                    13d79d632036|3063
# 3064                                         2037/09|3064
# 3077                                      2038650116|3077
# 3080                            sectors sectors 2033|3080
# 3081                                    yearbook2034|3081
# 3082                                  20370602035941|3082
# 3083                                    yearbook2036|3083
# 3085                                         2036-06|3085
# 3087                                         2035/03|3087
# 3095                                       faf.20363|3095
# 3103                                            2030|3103
# 3116                    ancla azul company solutions|3116
# 3117                                            pair|3117
# 3118                                          guessl|3118
# 3119                                       federated|3119
# 3120          finestsea ltd. corporation enterprises|3120
# 3121          icelandic shrimp corporation transport|3121
# 3122                         lake mweru a/s carriers|3122
# 3123                 playa de la felicidad oyj cargo|3123
# 3124                  l y s.a. de c.v. international|3124
# 3125                     seaspray wave srl solutions|3125
# 3126                             ocean fisheries llc|3126
# 3127                  ancla del mar ltd. corporation|3127
# 3128                               tamil nadu s.p.a.|3128
# 3129    fisherman'sfriend charter boat s.a. de c.v. fr...
# 3130                                            fiti|3130
# 3131                                        victoria|3131
# 3132                                          master|3132
# 3133                       faurtil fbrica urnas tiet|3133
# 3134    turkish mussels ltd. liability co marine biolo...
# 3135                     mar del paraso srl shipping|3135
# 3136                               new bedford light|3136
# 3137                             sonia fisheries pvt|3137
# 3138                                        pesquera|3138
# 3139                                            dofs|3139
# 3140    irish sea seaside gmbh & co. kg distribution|3140
# 3141                                uttar pradesh sp|3141
# 3142    estrella de coral ltd. corporation logistics|3142
# 3143                     gulf of guinea  corporation|3143
# 3144           seabreeze foods corporation logistics|3144
# 3145                                              do|3145
# 3146                       dry creek s.p.a. overseas|3146
# 3147                                  meere delpeuch|3147
# 3148         kerala market limited liability company|3148
# 3149                pasture petfoods new zealand ltd|3149
# 3150                                        tanzania|3150
# 3151                                         reunion|3151
# 3152                                     ht shipping|3152
# 3153                                 selena building|3153
# 3154                        playa de la felicidad nv|3154
# 3155                                         illegal|3155
# 3156                                          import|3156
# 3157                           fishing international|3157
# 3158                                        virginia|3158
# 3159                                      electronic|3159
# 3160                                        fish sea|3160
# 3161                                    sea products|3161
# 3162                                     w appliance|3162
# 3163                                         mcleans|3163
# 3164                                        american|3164
# 3165                 finest ltd. liability co united|3165
# 3166                                          ex-lax|3166
# 3167                                      fishisland|3167
# 3168    jammu & kashmir limited liability company deli...
# 3169                                             hes|3169
# 3170                                      noncitizen|3170
# 3171                                           genev|3171
# 3172                   oceanfront oasis inc carriers|3172
# 3173                        qingdao kaiyuan seafoods|3173
# 3174             west bengal srl marine conservation|3174
# 3175                                  platts oilgram|3175
# 3176                   kerala market corp consulting|3176
# 3177                             mar de la vida ojsc|3177
# 3178                                         america|3178
# 3179                 portuguese octopus s.p.a. cargo|3179
# 3180                 surf and sand ltd. liability co|3180
# 3181                        west bengal s.a. de c.v.|3181
# 3182                           partnership satellite|3182
# 3183                                         seafood|3183
# 3184                                       caribbean|3184
# 3185                                            xuar|3185
# 3186                                   fisheries inc|3186
# 3187                                       getis-ord|3187
# 3188                          world church power god|3188
# 3189                                   rama overseas|3189
# 3190    estrella de mar limited liability company deli...
# 3191                                        bergmans|3191
# 3192                                   conduct joint|3192
# 3193         seabreeze foods ltd. corporation united|3193
# 3194    kilimanjaro fishery ltd. liability co transpor...
# 3195                                             isa|3195
# 3196                    barco de plata ltd logistics|3196
# 3197                        lake malawi lc forwading|3197
# 3198                         water world llc express|3198
# 3199                                          trials|3199
# 3200                                             bps|3200
# 3201                            flip mcgyver tradema|3201
# 3202                              shellfish chile sa|3202
# 3203                                     ipos0000dop|3203
# 3204                                           temus|3204
# 3205                             firearms explosives|3205
# 3206                                           iavms|3206
# 3207                    cartel emergent weaponry use|3207
# 3208                           ejintex international|3208
# 3209                                    asia seafood|3209
# 3210                    andhra pradesh  s.a. de c.v.|3210
# 3211                                 atlantoscandian|3211
# 3212                                       trammells|3212
# 3213                                             moo|3213
# 3214                                             eva|3214
# 3215                   salles operation handroanthus|3215
# 3216           blue water ventures ltd. liability co|3216
# 3217                            mar de cristalino co|3217
# 3218            saltwatersavor shipyard lc merchants|3218
# 3219                oceankings sailor corp logistics|3219
# 3220                             debit cards autopay|3220
# 3221                      mar de la costa ges.m.b.h.|3221
# 3222                                        suffered|3222
# 3223                                          orient|3223
# 3224           oceanicharvest dry dock n.v. delivery|3224
# 3225                                             its|3225
# 3226                                         rafaels|3226
# 3227                        madhya pradesh market bv|3227
# 3228                                      compliance|3228
# 3229                                        blue bay|3229
# 3230                                      innovative|3230
# 3231                         lake malawi se freight |3231
# 3232           caspian sea  sea corporation freight |3232
# 3233                            yu gan bv investment|3233
# 3234                              thai union seafood|3234
# 3235    okavango delta seaside limited liability compa...
# 3236                             sh rn y corporation|3236
# 3237                                  ocean trawlers|3237
# 3238    belgian scallop limited liability company kril...
# 3239                                     sea harvest|3239
# 3240                                           smile|3240
# 3241                            haryana s co transit|3241
# 3242                                                |3242
# 3243                                  dofs long xing|3243
# 3244                                          insung|3244
# 3245                      chuan gou company overseas|3245
# 3246                       petroleum vapor intrusion|3246
# 3247                                energotrade plus|3247
# 3248                             intrepid navigators|3248
# 3249                                   blue venturew|3249
# 3250            the salty dog tidepool kga transport|3250
# 3251             madhya pradesh market ltd solutions|3251
# 3252    scottish trout limited liability company trans...
# 3253                               gen international|3253
# 3254                                      mewe vimeo|3254
# 3255                                            four|3255
# 3256                                              ii|3256
# 3257                                       bloomberg|3257
# 3258                                           ntaco|3258
# 3259                                            svbs|3259
# 3260                                    united bankx|3260
# 3261                                   golden titana|3261
# 3262            sea breezes gmbh & co. kg lighthouse|3262
# 3263                     mar de plata corp and son's|3263
# 3264                                              rs|3264
# 3265                          irish sea srl brothers|3265
# 3266                              barco de plata plc|3266
# 3267                          thomas corp cargo ship|3267
# 3268    blue lagoon sailor limited liability company w...
# 3269                                 amorim flooring|3269
# 3270                  edward ferry se transportation|3270
# 3271                                               1|3271
# 3272                                        stock sa|3272
# 3273                          forwading s.a. de c.v.|3273
# 3274     oceanicorigin foods river ag marine ecology|3274
# 3275                                            ware|3275
# 3276                                          arctic|3276
# 3277           niger river delta ges.m.b.h. services|3277
# 3278                                      robyn beck|3278
# 3279                    bay of bengal's incorporated|3279
# 3280      aqua ambassadors limited liability company|3280
# 3281        sea luxe oceanography kga transportation|3281
# 3282                                       mongabays|3282
# 3283                                  fresh atlantic|3283
# 3284                                            suns|3284
# 3285                            costa del mar s.p.a.|3285
# 3286                          ojsc ltd. liability co|3286
# 3287                 mount kenya estuary sp holdings|3287
# 3288                                          pokmon|3288
# 3289                                       ryabikova|3289
# 3290                                      bracatinga|3290
# 3291                                      i6ae01vdfm|3291
# 3292                                          puerta|3292
# 3293                                        next day|3293
# 3294                   seaside sojourns a/s shipping|3294
# 3295                                            food|3295
# 3296      guaranteed income program new parents 2035|3296
# 3297                                  image arttower|3297
# 3298            nile crocodile deep-sea oyj brothers|3298
# 3299                                      vyoummbnvy|3299
# 3300                         blue water ventures kga|3300
# 3301                                   bloomberg law|3301
# 3302                                          cinder|3302
# 3303                       kariba dam  n.v. brothers|3303
# 3304                                      mitsubishi|3304
# 3305                                    tuna vietnam|3305
# 3306                            estrella del mar plc|3306
# 3307                                    marine foods|3307
# 3308                         agua transicin ecolgica|3308
# 3309                arunachal pradesh sp marine mist|3309
# 3310            chuan gou corporation transportation|3310
# 3311                  nautical navigators kga united|3311
# 3312                             3 ltd. liability co|3312
# 3313                                       lf beauty|3313
# 3314                playa de coral oyj international|3314
# 3315                                   metro marinen|3315
# 3316             surf and sea international tidepool|3316
# 3317                              the salty dog cjsc|3317
# 3318                               paul s.a. de c.v.|3318
# 3319                                        comei&co|3319
# 3320                                  rickard shrimp|3320
# 3321                                     hudsons bay|3321
# 3322                            group co marine life|3322
# 3323                                             stl|3323
# 3324             odisha sea dry dock llc consultants|3324
# 3325                                           usinc|3325
# 3326                                       the ashey|3326
# 3327                                           green|3327
# 3328               dark web vendor illegal narcotics|3328
# 3329                 heroin cocaine exchange bitcoin|3329
# 3330                                         farmers|3330
# 3331                                           fitis|3331
# 3332                       jharkhand s gmbh & co. kg|3332
# 3333                                        phillips|3333
# 3334                           6 ray llc enterprises|3334
# 3335                                            prod|3335
# 3336                                      pinduoduos|3336
# 3337                                           auras|3337
# 3338                                    mcgovern bbb|3338
# 3339                                            rose|3339
# 3340                               drayage companies|3340
# 3341                savaneta corporation marine life|3341
# 3342               michael limited liability company|3342
# 3343                       irtysh - inc distribution|3343
# 3344                                            east|3344
# 3345                           fresh on time seafood|3345
# 3346                                             mat|3346
# 3347                       faroe islands halibut a/s|3347
# 3348                            teion internationala|3348
# 3349                                  single seafood|3349
# 3350                                              us|3350
# 3351                                         welding|3351
# 3352                                      basketball|3352
# 3353                                   ocean packers|3353
# 3354                                 improvised anti|3354
# 3355                      orange river  as logistics|3355
# 3356                                             ste|3356
# 3357               french ltd. corporation surfboard|3357
# 3358             andhra pradesh  investment dry dock|3358
# 3359                                    uber connect|3359
# 3360                            pb brasil industries|3360
# 3361                            deep sea atlantic nv|3361
# 3362                supreme gmbh & co. kg consulting|3362
# 3363                                gu y lc shipping|3363
# 3364               ningbo china base landhau foreign|3364
# 3365                            estrella del mar pic|3365
# 3366                          artemovs ava petroleum|3366
# 3367               spanish red snapper gmbh shipping|3367
# 3368                           officer pleads guilty|3368
# 3369            bribes exchange smuggling contraband|3369
# 3370                                              sp|3370
# 3371                                   memphis women|3371
# 3372                                       one hongn|3372
# 3373                                       evergreen|3373
# 3374           himachal pradesh aquatic plc brothers|3374
# 3375                 lake tanganyika sea as shipping|3375
# 3376                nagaland sea ltd. liability co &|3376
# 3377               estrella de la costa  consultants|3377
# 3378                          kores de venezuela c a|3378
# 3379                                        cp world|3379
# 3380                                          tombow|3380
# 3381                                 gelita gelatine|3381
# 3382                                            yale|3382
# 3383                    faroe islands plc investment|3383
# 3384                east ltd. corporation investment|3384
# 3385                                       logistics|3385
# 3386                                     dispenseroo|3386
# 3387                                 80 percent arms|3387
# 3388                                    cm nationali|3388
# 3389                    anthony sailboat co shipping|3389
# 3390                                              mv|3390
# 3391        costa de coral charter boat oyj overseas|3391
# 3392                                          warner|3392
# 3393                                  alpha brokersa|3393
# 3394                                         viktors|3394
# 3395               sea seekers merchants cruise ship|3395
# 3396                                            nfts|3396
# 3397                                  cargo systemsi|3397
# 3398                    ocano del este corp freight |3398
# 3399                                          ronald|3399
# 3400                                       c express|3400
# 3401                         znamensk eel llc united|3401
# 3402                                 sisdof/sinaflor|3402
# 3403                      spanish shrimp sp brothers|3403
# 3404                           tajima industrues ltd|3404
# 3405                                          zerzas|3405
# 3406                      indstria madeireira uliana|3406
# 3407                                             sms|3407
# 3408                                 semas 260 rural|3408
# 3409             dolphin dreams s.a. de c.v. seafood|3409
# 3410                                             all|3410
# 3411                               cab incorportated|3411
# 3412                             sikkim s.a. de c.v.|3412
# 3413                                           yeezy|3413
# 3414                 kagera river  company solutions|3414
# 3415                  marmooska shipyard sagl united|3415
# 3416                                             leo|3416
# 3417                                      w&o supply|3417
# 3418    greek sea bream limited liability company tran...
# 3419                     david s.a. de c.v. brothers|3419
# 3420             haryana s ltd. corporation carriers|3420
# 3421                       coral reef sagl transport|3421
# 3422                                    felbab-brown|3422
# 3423                                     ozonactions|3423
# 3424                                        entirely|3424
# 3425                               ocano del este se|3425
# 3426                         norwegian shrimp n.v. -|3426
# 3427                            malabar sea catch sp|3427
# Name: id, dtype: object

# %% [markdown]
# ## Add type 'unknown' for nodes without type

# %%
for node in data['nodes']:
    node['type'] = node.get('type', 'unknown')

# %% [markdown]
# ## Illgality classification
#
# ### Create feature vectors
#
# Create a vector for each node. The vector should contain:
# * the node category, as a one-hot vector
# * for each edge type, the weighted fraction (outgoing edges of that type / all outgoing edges)
# * for each edge type, the weighted fraction (incoming edges of that type / all incoming edges)
# * the number of incoming edges
# * the number of outgoing edges
# * the betweenness centrality of the node

# %%
import json
import networkx as nx
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# Load your data
# data = json.loads(your_json_string)

# Convert data to the format required by networkx
G = nx.MultiDiGraph()
for node in data['nodes']:
    G.add_node(node['id'], attr_dict=node)
for edge in data['edges']:
    G.add_edge(edge['source'], edge['target'], attr_dict=edge)
    
    
# Remove nodes from disconnected components
import operator
## Compute all weakly connected components
components = list(nx.weakly_connected_components(G))
## Find the largest component
largest_component = max(components, key=len)
## Create a new graph that only contains the largest component
G = G.subgraph(largest_component).copy()

# Define categories for one-hot encoding
categories = np.array(sorted(list(set([node['type'] for node in data['nodes'] if node['type'] != 'unknown'])))).reshape(-1, 1)
one_hot_encoder = OneHotEncoder(sparse=False)
one_hot_encoder.fit(categories)

betweenness_centralities = nx.betweenness_centrality(G)
pagerank_scores = nx.pagerank(G)

# Compute feature vectors
feature_vectors = dict()
for node in G.nodes(data=True):
    feature_vector = []
    
    if node[1]['attr_dict']['type'] == 'unknown':
        feature_vector.extend(np.array([1/len(categories)] * len(categories)))
    else:
        ohv = one_hot_encoder.transform([[node[1]['attr_dict']['type']]])
        feature_vector.extend(ohv[0])
        
    # Weighted fractions of outgoing and incoming edges
    for edge_type in ['family_relationship', 'partnership', 'membership', 'ownership']: # Update this list with your edge types
        outgoing_edges = [edge[2]['attr_dict']['weight'] for edge in G.out_edges(node[0], data=True) if edge[2]['attr_dict']['type'] == edge_type]
        incoming_edges = [edge[2]['attr_dict']['weight'] for edge in G.in_edges(node[0], data=True) if edge[2]['attr_dict']['type'] == edge_type]
        feature_vector.append(sum(outgoing_edges) / sum([edge[2]['attr_dict']['weight'] for edge in G.out_edges(node[0], data=True)]) if G.out_edges(node[0], data=True) else 0)
        feature_vector.append(sum(incoming_edges) / sum([edge[2]['attr_dict']['weight'] for edge in G.in_edges(node[0], data=True)]) if G.in_edges(node[0], data=True) else 0)
    
    # Number of incoming and outgoing edges
    feature_vector.append(G.in_degree(node[0]))
    feature_vector.append(G.out_degree(node[0]))
    feature_vector.append(betweenness_centralities[node[0]])
    feature_vector.append(pagerank_scores[node[0]])
    feature_vectors[node[0]] = feature_vector

# %% [markdown]
# ### Fit model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# List of illegal node IDs
illegal_nodes = [
  "armed robbery|166",
  "game thief|1371",
  "illegal|2568",
  "deepwater horizon|2680",
  "shabu|2987",
  "shark fin|3043",
  "illegal|3155",
  "cartel emergent weaponry use|3207",
  "dark web vendor illegal narcotics|3328",
  "heroin cocaine exchange bitcoin|3329",
  "officer pleads guilty|3368",
  "bribes exchange smuggling contraband|3369"
]

# Create a list of (node_id, label) pairs
node_labels = [(node_id, 1 if node_id in illegal_nodes else 0) for node_id in feature_vectors.keys()]

# Sort the list by node_id to ensure consistent order
node_labels.sort(key=lambda x: x[0])

# Separate the node IDs and labels into two lists
node_ids, labels = zip(*node_labels)

# Use the same order to generate the feature vectors
feature_vector_list = [feature_vectors[node_id] for node_id in node_ids]


# List of feature descriptions
feature_descriptions = ['Type: ' + cat for cat in categories[:,0]] + \
                       ['Outgoing fraction: family_relationship', 'Incoming fraction: family_relationship',
                        'Outgoing fraction: partnership', 'Incoming fraction: partnership',
                        'Number of incoming edges', 'Number of outgoing edges', 
                        'Betweenness centrality', 'Pagerank']

# %%
# Scale feature vectors
scaler = StandardScaler()
feature_vector_list_scaled = scaler.fit_transform(feature_vector_list)

# Define logistic regression model with L1 regularization
model = LogisticRegression(penalty='l1', solver='liblinear', random_state=42, C=1.0)

# Fit the model
model.fit(feature_vector_list_scaled, labels)

# Get the coefficients
coefs = model.coef_[0]
intercept = model.intercept_

# Print the intercept and coefficients
print("Intercept: ", intercept)
for feature_description, coef in zip(feature_descriptions, coefs):
    print(f"{feature_description}: {coef}")
# Out:
# Intercept:  [-6.30916357]
# Type: company: 0.23971944192235503
# Type: event: 0.21208654936861596
# Type: location: 0.0
# Type: movement: 0.24814192753586592
# Type: organization: -0.17143348973739228
# Type: person: -0.023198581533754228
# Type: political_organization: 0.22017107649605233
# Type: vessel: 0.30851775762546485
# Outgoing fraction: family_relationship: -0.4628879244447966
# Incoming fraction: family_relationship: -0.5180756557070315
# Outgoing fraction: partnership: 0.28570803263470756
# Incoming fraction: partnership: 0.0
# Number of incoming edges: -0.24142438840671115
# Number of outgoing edges: 0.44937987540996455
# Betweenness centrality: -0.288728108009589
# Pagerank: 0.0

# %% [markdown]
# ### Predict illegality on all training data and export it into a json dictionary.

# %%
# Predict the probabilities
probabilities = model.predict_proba(feature_vector_list_scaled)[:, 1]

# Create a dictionary that maps each node id to its probability
id_to_probability = {id: probability for id, probability in zip(feature_vectors.keys(), probabilities)}
# Sort the dictionary by probability, highest first
sorted_id_to_probability = sorted(id_to_probability.items(), key=lambda item: item[1], reverse=True)

# Export the sorted dictionary to a json file
with open('node_id_to_probability.json', 'w') as f:
    json.dump(dict(sorted_id_to_probability), f, indent=1)
